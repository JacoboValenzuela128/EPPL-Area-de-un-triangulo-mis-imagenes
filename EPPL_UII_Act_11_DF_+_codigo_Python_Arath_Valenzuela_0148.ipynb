# %% [markdown]
# <a href="https://colab.research.google.com/github/JacoboValenzuela128/EPPL-Area-de-un-triangulo-mis-imagenes/blob/main/EPPL_UII_Act_11_DF_%2B_codigo_Python_Arath_Valenzuela_0148.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Arath Valenzuela NL:52 fecha 25/3/26
# ---
# # Calcular el area de un triangulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/JacoboValenzuela128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/Area_de_un_triangulo.png)
#
# ---
# ## Formula para calcular area
# $A = (b * h)/2$
# ---
# ## Datos de entrada
# * $b=?$
# * $h=?$
# ---
# ## Diagrama de flujo en lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/JacoboValenzuela128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/DF%20Area%20triangulo.png)

# %%
# Calcular area de un triangulo rectangulo
# Variables h, b
# Formula A = (b * h)/2
# Capturar el valor de las variables
import math
print("Calcular el area de un triangulo rectangulo")
b = int(input("Ingrese la base del triangulo: "))
h = int(input("Ingrese la altura del triangulo: "))
a = (b * h)/2
print("El area del triangulo es: ", a)
print("Arath Valenzuela NL:52")
# Out:
# Calcular el area de un triangulo rectangulo
# Ingrese la altura del triangulo: 14
# Ingrese la base del triangulo: 23
# El area del triangulo es:  161.0
# Arath Valenzuela NL:52

# %% [markdown]
# # Relacion entre el codigo y diagrama de flujo en TLdraw
# ![Logo de Markdown](https://raw.githubusercontent.com/JacoboValenzuela128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/TLdraw%20DF%20y%20codigo.png)
